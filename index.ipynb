# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
theta = np.arange(0.0, 2*np.pi, 1.e-3)
x = (1+np.cos(theta))*np.cos(theta)
y = (1+np.cos(theta))*np.sin(theta)

# %%
plt.figure(figsize=(6,6))
plt.plot(x, y, '-')
plt.show()
