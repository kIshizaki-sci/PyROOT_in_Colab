# %% [markdown]
# # PyROOT for Google Colaboratory
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://drive.google.com/file/d/1FeIbfUvj4MayUf8He5lsKfnti-Pb7ytT/view?usp=sharing)
#
# GitHub repository : [https://github.com/kIshizaki-sci/PyROOT_in_Colab](https://github.com/kIshizaki-sci/PyROOT_in_Colab)
# Author : Kohei ISHIZAKI (石崎 貢平) , Nagoya Univ.
# LICENSE : LGPL 2.1 (Refer the GitHub repository for details.)

# %%
import os
import sys

sys.path.insert(1, "/opt/root/lib")
os.environ["ROOTSYS"]="/opt/root"
os.environ["PATH"]=os.environ["ROOTSYS"]+"/bin:"+os.environ["PATH"]
os.environ["PYTHONPATH"]=os.environ["ROOTSYS"]+"/lib:"+os.environ["PYTHONPATH"]
os.environ["CLING_STANDARD_PCH"]="none"

# %%
# %%bash
# apt update
# apt install -yq --no-install-recommends \
#     run-one build-essential inkscape lmodern netcat tzdata llvm-dev
# apt install -yq --no-install-recommends \
#     binutils libxpm-dev xlibmesa-glu-dev libglew1.5-dev libftgl-dev libfftw3-dev libcfitsio-dev \
#     graphviz-dev libavahi-compat-libdnssd-dev libldap2-dev libkrb5-dev libgsl0-dev
# git clone https://github.com/kIshizaki-sci/PyROOT_in_Colab.git --depth 1
# cat PyROOT_in_Colab/root-bin/root-*-bin*tar.xz-* > /tmp/root-bin.tar.xz
# tar Jxfv /tmp/root-bin.tar.xz -C /opt
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:6 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:9 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:12 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:13 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:14 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,431 kB]
# Hit:16 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,365 kB]
# Get:18 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,802 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,210 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,801 kB]
# Get:21 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [922 kB]
# Get:22 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [40.8 kB]
# Fetched 11.9 MB in 4s (2,814 kB/s)
# Reading package lists...
# Building dependency tree...
# Reading state information...
# 39 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# build-essential is already the newest version (12.4ubuntu1).
# The following additional packages will be installed:
#   aspell aspell-en binfmt-support dictionaries-common emacsen-common
#   fonts-lmodern imagemagick-6-common libaspell15 libatkmm-1.6-1v5
#   libcairomm-1.0-1v5 libcdr-0.1-1 libdbus-glib-1-2 libenchant1c2a libffi-dev
#   libglibmm-2.4-1v5 libgsl23 libgslcblas0 libgtk2.0-0 libgtk2.0-common
#   libgtkmm-2.4-1v5 libgtkspell0 libhunspell-1.6-0 liblqr-1-0
#   libmagick++-6.q16-7 libmagickcore-6.q16-3 libmagickwand-6.q16-3
#   libpangomm-1.4-1v5 libpoppler-glib8 libpotrace0 librevenge-0.0-0
#   libsigc++-2.0-0v5 libtext-iconv-perl libvisio-0.1-1 libwpd-0.10-10
#   libwpg-0.3-3 llvm llvm-6.0 llvm-6.0-dev llvm-6.0-runtime llvm-runtime
#   netcat-traditional tex-common
# Suggested packages:
#   aspell-doc spellutils wordlist dia libsvg-perl libxml-xql-perl pstoedit
#   python-uniconvertor ruby libenchant-voikko gsl-ref-psdoc | gsl-doc-pdf
#   | gsl-doc-info | gsl-ref-html gvfs libmagickcore-6.q16-3-extra llvm-6.0-doc
#   debhelper
# Recommended packages:
#   imagemagick libimage-magick-perl libwmf-bin python-lxml python-scour
#   transfig enchant libgail-common libgtk2.0-bin hunspell-en-us
#   | hunspell-dictionary | myspell-dictionary ghostscript gsfonts
# The following NEW packages will be installed:
#   aspell aspell-en binfmt-support dictionaries-common emacsen-common
#   fonts-lmodern imagemagick-6-common inkscape libaspell15 libatkmm-1.6-1v5
#   libcairomm-1.0-1v5 libcdr-0.1-1 libdbus-glib-1-2 libenchant1c2a libffi-dev
#   libglibmm-2.4-1v5 libgsl23 libgslcblas0 libgtk2.0-0 libgtk2.0-common
#   libgtkmm-2.4-1v5 libgtkspell0 libhunspell-1.6-0 liblqr-1-0
#   libmagick++-6.q16-7 libmagickcore-6.q16-3 libmagickwand-6.q16-3
#   libpangomm-1.4-1v5 libpoppler-glib8 libpotrace0 librevenge-0.0-0
#   libsigc++-2.0-0v5 libtext-iconv-perl libvisio-0.1-1 libwpd-0.10-10
#   libwpg-0.3-3 llvm llvm-6.0 llvm-6.0-dev llvm-6.0-runtime llvm-dev
#   llvm-runtime lmodern netcat netcat-traditional run-one tex-common
# The following packages will be upgraded:
#   tzdata
# 1 upgraded, 47 newly installed, 0 to remove and 38 not upgraded.
# Need to get 68.0 MB of archives.
# After this operation, 387 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 liblqr-1-0 amd64 0.4.2-2.1 [27.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 imagemagick-6-common all 8:6.9.7.4+dfsg-16ubuntu6.11 [60.2 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickcore-6.q16-3 amd64 8:6.9.7.4+dfsg-16ubuntu6.11 [1,619 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickwand-6.q16-3 amd64 8:6.9.7.4+dfsg-16ubuntu6.11 [294 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 tex-common all 6.09 [33.0 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtext-iconv-perl amd64 1.7-5build6 [13.0 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 tzdata all 2021a-2ubuntu0.18.04 [191 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libaspell15 amd64 0.60.7~20110707-4ubuntu0.2 [310 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 emacsen-common all 2.0.8 [17.6 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 dictionaries-common all 1.27.2 [186 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 aspell amd64 0.60.7~20110707-4ubuntu0.2 [87.7 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 aspell-en all 2017.08.24-0-0.1 [298 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 binfmt-support amd64 2.1.8-2 [51.6 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-lmodern all 2.004.5-3 [4,551 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsigc++-2.0-0v5 amd64 2.10.0-2 [10.9 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 libglibmm-2.4-1v5 amd64 2.56.0-1 [516 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatkmm-1.6-1v5 amd64 2.24.2-3 [62.6 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcairomm-1.0-1v5 amd64 1.12.2-3 [37.1 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 librevenge-0.0-0 amd64 0.0.4-6ubuntu2 [203 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcdr-0.1-1 amd64 0.1.4-1build1 [333 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdbus-glib-1-2 amd64 0.110-2 [58.3 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgslcblas0 amd64 2.4+dfsg-6 [79.7 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgsl23 amd64 2.4+dfsg-6 [823 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-common all 2.24.32-1ubuntu1 [125 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-0 amd64 2.24.32-1ubuntu1 [1,769 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpangomm-1.4-1v5 amd64 2.40.1-4 [42.5 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtkmm-2.4-1v5 amd64 1:2.24.5-2 [666 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhunspell-1.6-0 amd64 1.6.2-1 [154 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic/main amd64 libenchant1c2a amd64 1.6.0-11.1 [64.4 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgtkspell0 amd64 2.0.16-1.2 [20.4 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagick++-6.q16-7 amd64 8:6.9.7.4+dfsg-16ubuntu6.11 [139 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpoppler-glib8 amd64 0.62.0-2ubuntu2.12 [108 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpotrace0 amd64 1.14-2 [17.4 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/main amd64 libvisio-0.1-1 amd64 0.1.6-1build1 [210 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwpd-0.10-10 amd64 0.10.2-2 [161 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwpg-0.3-3 amd64 0.3.1-3 [44.6 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic/universe amd64 inkscape amd64 0.92.3-1 [16.7 MB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic/main amd64 llvm-6.0-runtime amd64 1:6.0-1ubuntu2 [200 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 llvm-runtime amd64 1:6.0-41~exp5~ubuntu1 [2,856 B]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/main amd64 llvm-6.0 amd64 1:6.0-1ubuntu2 [4,838 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 llvm amd64 1:6.0-41~exp5~ubuntu1 [3,468 B]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/main amd64 libffi-dev amd64 3.2.1-8 [156 kB]
# Get:43 http://archive.ubuntu.com/ubuntu bionic/main amd64 llvm-6.0-dev amd64 1:6.0-1ubuntu2 [23.0 MB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 llvm-dev amd64 1:6.0-41~exp5~ubuntu1 [1,860 B]
# Get:45 http://archive.ubuntu.com/ubuntu bionic/main amd64 lmodern all 2.004.5-3 [9,631 kB]
# Get:46 http://archive.ubuntu.com/ubuntu bionic/universe amd64 netcat-traditional amd64 1.10-41.1 [61.7 kB]
# Get:47 http://archive.ubuntu.com/ubuntu bionic/universe amd64 netcat all 1.10-41.1 [3,436 B]
# Get:48 http://archive.ubuntu.com/ubuntu bionic/main amd64 run-one all 1.17-0ubuntu1 [5,760 B]
# Preconfiguring packages ...
# Fetched 68.0 MB in 5s (13.9 MB/s)
# Selecting previously unselected package liblqr-1-0:amd64.
# (Reading database ... 155047 files and directories currently installed.)
# Preparing to unpack .../00-liblqr-1-0_0.4.2-2.1_amd64.deb ...
# Unpacking liblqr-1-0:amd64 (0.4.2-2.1) ...
# Selecting previously unselected package imagemagick-6-common.
# Preparing to unpack .../01-imagemagick-6-common_8%3a6.9.7.4+dfsg-16ubuntu6.11_all.deb ...
# Unpacking imagemagick-6-common (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Selecting previously unselected package libmagickcore-6.q16-3:amd64.
# Preparing to unpack .../02-libmagickcore-6.q16-3_8%3a6.9.7.4+dfsg-16ubuntu6.11_amd64.deb ...
# Unpacking libmagickcore-6.q16-3:amd64 (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Selecting previously unselected package libmagickwand-6.q16-3:amd64.
# Preparing to unpack .../03-libmagickwand-6.q16-3_8%3a6.9.7.4+dfsg-16ubuntu6.11_amd64.deb ...
# Unpacking libmagickwand-6.q16-3:amd64 (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Selecting previously unselected package tex-common.
# Preparing to unpack .../04-tex-common_6.09_all.deb ...
# Unpacking tex-common (6.09) ...
# Selecting previously unselected package libtext-iconv-perl.
# Preparing to unpack .../05-libtext-iconv-perl_1.7-5build6_amd64.deb ...
# Unpacking libtext-iconv-perl (1.7-5build6) ...
# Preparing to unpack .../06-tzdata_2021a-2ubuntu0.18.04_all.deb ...
# Unpacking tzdata (2021a-2ubuntu0.18.04) over (2021a-0ubuntu0.18.04) ...
# Selecting previously unselected package libaspell15:amd64.
# Preparing to unpack .../07-libaspell15_0.60.7~20110707-4ubuntu0.2_amd64.deb ...
# Unpacking libaspell15:amd64 (0.60.7~20110707-4ubuntu0.2) ...
# Selecting previously unselected package emacsen-common.
# Preparing to unpack .../08-emacsen-common_2.0.8_all.deb ...
# Unpacking emacsen-common (2.0.8) ...
# Selecting previously unselected package dictionaries-common.
# Preparing to unpack .../09-dictionaries-common_1.27.2_all.deb ...
# Adding 'diversion of /usr/share/dict/words to /usr/share/dict/words.pre-dictionaries-common by dictionaries-common'
# Unpacking dictionaries-common (1.27.2) ...
# Selecting previously unselected package aspell.
# Preparing to unpack .../10-aspell_0.60.7~20110707-4ubuntu0.2_amd64.deb ...
# Unpacking aspell (0.60.7~20110707-4ubuntu0.2) ...
# Selecting previously unselected package aspell-en.
# Preparing to unpack .../11-aspell-en_2017.08.24-0-0.1_all.deb ...
# Unpacking aspell-en (2017.08.24-0-0.1) ...
# Selecting previously unselected package binfmt-support.
# Preparing to unpack .../12-binfmt-support_2.1.8-2_amd64.deb ...
# Unpacking binfmt-support (2.1.8-2) ...
# Selecting previously unselected package fonts-lmodern.
# Preparing to unpack .../13-fonts-lmodern_2.004.5-3_all.deb ...
# Unpacking fonts-lmodern (2.004.5-3) ...
# Selecting previously unselected package libsigc++-2.0-0v5:amd64.
# Preparing to unpack .../14-libsigc++-2.0-0v5_2.10.0-2_amd64.deb ...
# Unpacking libsigc++-2.0-0v5:amd64 (2.10.0-2) ...
# Selecting previously unselected package libglibmm-2.4-1v5:amd64.
# Preparing to unpack .../15-libglibmm-2.4-1v5_2.56.0-1_amd64.deb ...
# Unpacking libglibmm-2.4-1v5:amd64 (2.56.0-1) ...
# Selecting previously unselected package libatkmm-1.6-1v5:amd64.
# Preparing to unpack .../16-libatkmm-1.6-1v5_2.24.2-3_amd64.deb ...
# Unpacking libatkmm-1.6-1v5:amd64 (2.24.2-3) ...
# Selecting previously unselected package libcairomm-1.0-1v5:amd64.
# Preparing to unpack .../17-libcairomm-1.0-1v5_1.12.2-3_amd64.deb ...
# Unpacking libcairomm-1.0-1v5:amd64 (1.12.2-3) ...
# Selecting previously unselected package librevenge-0.0-0:amd64.
# Preparing to unpack .../18-librevenge-0.0-0_0.0.4-6ubuntu2_amd64.deb ...
# Unpacking librevenge-0.0-0:amd64 (0.0.4-6ubuntu2) ...
# Selecting previously unselected package libcdr-0.1-1:amd64.
# Preparing to unpack .../19-libcdr-0.1-1_0.1.4-1build1_amd64.deb ...
# Unpacking libcdr-0.1-1:amd64 (0.1.4-1build1) ...
# Selecting previously unselected package libdbus-glib-1-2:amd64.
# Preparing to unpack .../20-libdbus-glib-1-2_0.110-2_amd64.deb ...
# Unpacking libdbus-glib-1-2:amd64 (0.110-2) ...
# Selecting previously unselected package libgslcblas0:amd64.
# Preparing to unpack .../21-libgslcblas0_2.4+dfsg-6_amd64.deb ...
# Unpacking libgslcblas0:amd64 (2.4+dfsg-6) ...
# Selecting previously unselected package libgsl23:amd64.
# Preparing to unpack .../22-libgsl23_2.4+dfsg-6_amd64.deb ...
# Unpacking libgsl23:amd64 (2.4+dfsg-6) ...
# Selecting previously unselected package libgtk2.0-common.
# Preparing to unpack .../23-libgtk2.0-common_2.24.32-1ubuntu1_all.deb ...
# Unpacking libgtk2.0-common (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../24-libgtk2.0-0_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libpangomm-1.4-1v5:amd64.
# Preparing to unpack .../25-libpangomm-1.4-1v5_2.40.1-4_amd64.deb ...
# Unpacking libpangomm-1.4-1v5:amd64 (2.40.1-4) ...
# Selecting previously unselected package libgtkmm-2.4-1v5:amd64.
# Preparing to unpack .../26-libgtkmm-2.4-1v5_1%3a2.24.5-2_amd64.deb ...
# Unpacking libgtkmm-2.4-1v5:amd64 (1:2.24.5-2) ...
# Selecting previously unselected package libhunspell-1.6-0:amd64.
# Preparing to unpack .../27-libhunspell-1.6-0_1.6.2-1_amd64.deb ...
# Unpacking libhunspell-1.6-0:amd64 (1.6.2-1) ...
# Selecting previously unselected package libenchant1c2a:amd64.
# Preparing to unpack .../28-libenchant1c2a_1.6.0-11.1_amd64.deb ...
# Unpacking libenchant1c2a:amd64 (1.6.0-11.1) ...
# Selecting previously unselected package libgtkspell0:amd64.
# Preparing to unpack .../29-libgtkspell0_2.0.16-1.2_amd64.deb ...
# Unpacking libgtkspell0:amd64 (2.0.16-1.2) ...
# Selecting previously unselected package libmagick++-6.q16-7:amd64.
# Preparing to unpack .../30-libmagick++-6.q16-7_8%3a6.9.7.4+dfsg-16ubuntu6.11_amd64.deb ...
# Unpacking libmagick++-6.q16-7:amd64 (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Selecting previously unselected package libpoppler-glib8:amd64.
# Preparing to unpack .../31-libpoppler-glib8_0.62.0-2ubuntu2.12_amd64.deb ...
# Unpacking libpoppler-glib8:amd64 (0.62.0-2ubuntu2.12) ...
# Selecting previously unselected package libpotrace0.
# Preparing to unpack .../32-libpotrace0_1.14-2_amd64.deb ...
# Unpacking libpotrace0 (1.14-2) ...
# Selecting previously unselected package libvisio-0.1-1:amd64.
# Preparing to unpack .../33-libvisio-0.1-1_0.1.6-1build1_amd64.deb ...
# Unpacking libvisio-0.1-1:amd64 (0.1.6-1build1) ...
# Selecting previously unselected package libwpd-0.10-10:amd64.
# Preparing to unpack .../34-libwpd-0.10-10_0.10.2-2_amd64.deb ...
# Unpacking libwpd-0.10-10:amd64 (0.10.2-2) ...
# Selecting previously unselected package libwpg-0.3-3:amd64.
# Preparing to unpack .../35-libwpg-0.3-3_0.3.1-3_amd64.deb ...
# Unpacking libwpg-0.3-3:amd64 (0.3.1-3) ...
# Selecting previously unselected package inkscape.
# Preparing to unpack .../36-inkscape_0.92.3-1_amd64.deb ...
# Unpacking inkscape (0.92.3-1) ...
# Selecting previously unselected package llvm-6.0-runtime.
# Preparing to unpack .../37-llvm-6.0-runtime_1%3a6.0-1ubuntu2_amd64.deb ...
# Unpacking llvm-6.0-runtime (1:6.0-1ubuntu2) ...
# Selecting previously unselected package llvm-runtime.
# Preparing to unpack .../38-llvm-runtime_1%3a6.0-41~exp5~ubuntu1_amd64.deb ...
# Unpacking llvm-runtime (1:6.0-41~exp5~ubuntu1) ...
# Selecting previously unselected package llvm-6.0.
# Preparing to unpack .../39-llvm-6.0_1%3a6.0-1ubuntu2_amd64.deb ...
# Unpacking llvm-6.0 (1:6.0-1ubuntu2) ...
# Selecting previously unselected package llvm.
# Preparing to unpack .../40-llvm_1%3a6.0-41~exp5~ubuntu1_amd64.deb ...
# Unpacking llvm (1:6.0-41~exp5~ubuntu1) ...
# Selecting previously unselected package libffi-dev:amd64.
# Preparing to unpack .../41-libffi-dev_3.2.1-8_amd64.deb ...
# Unpacking libffi-dev:amd64 (3.2.1-8) ...
# Selecting previously unselected package llvm-6.0-dev.
# Preparing to unpack .../42-llvm-6.0-dev_1%3a6.0-1ubuntu2_amd64.deb ...
# Unpacking llvm-6.0-dev (1:6.0-1ubuntu2) ...
# Selecting previously unselected package llvm-dev.
# Preparing to unpack .../43-llvm-dev_1%3a6.0-41~exp5~ubuntu1_amd64.deb ...
# Unpacking llvm-dev (1:6.0-41~exp5~ubuntu1) ...
# Selecting previously unselected package lmodern.
# Preparing to unpack .../44-lmodern_2.004.5-3_all.deb ...
# Unpacking lmodern (2.004.5-3) ...
# Selecting previously unselected package netcat-traditional.
# Preparing to unpack .../45-netcat-traditional_1.10-41.1_amd64.deb ...
# Unpacking netcat-traditional (1.10-41.1) ...
# Selecting previously unselected package netcat.
# Preparing to unpack .../46-netcat_1.10-41.1_all.deb ...
# Unpacking netcat (1.10-41.1) ...
# Selecting previously unselected package run-one.
# Preparing to unpack .../47-run-one_1.17-0ubuntu1_all.deb ...
# Unpacking run-one (1.17-0ubuntu1) ...
# Setting up imagemagick-6-common (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Setting up binfmt-support (2.1.8-2) ...
# Created symlink /etc/systemd/system/multi-user.target.wants/binfmt-support.service → /lib/systemd/system/binfmt-support.service.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libpoppler-glib8:amd64 (0.62.0-2ubuntu2.12) ...
# Setting up libgtk2.0-common (2.24.32-1ubuntu1) ...
# Setting up tex-common (6.09) ...
# update-language: texlive-base not installed and configured, doing nothing!
# Setting up libhunspell-1.6-0:amd64 (1.6.2-1) ...
# Setting up libaspell15:amd64 (0.60.7~20110707-4ubuntu0.2) ...
# Setting up libdbus-glib-1-2:amd64 (0.110-2) ...
# Setting up tzdata (2021a-2ubuntu0.18.04) ...
#
# Current default time zone: 'Etc/UTC'
# Local time is now:      Thu Oct  7 21:41:59 UTC 2021.
# Universal Time is now:  Thu Oct  7 21:41:59 UTC 2021.
# Run 'dpkg-reconfigure tzdata' if you wish to change it.
#
# Setting up run-one (1.17-0ubuntu1) ...
# Setting up emacsen-common (2.0.8) ...
# Setting up netcat-traditional (1.10-41.1) ...
# update-alternatives: using /bin/nc.traditional to provide /bin/nc (nc) in auto mode
# Setting up libffi-dev:amd64 (3.2.1-8) ...
# Setting up librevenge-0.0-0:amd64 (0.0.4-6ubuntu2) ...
# Setting up llvm-6.0-runtime (1:6.0-1ubuntu2) ...
# Setting up llvm-runtime (1:6.0-41~exp5~ubuntu1) ...
# Setting up liblqr-1-0:amd64 (0.4.2-2.1) ...
# Setting up libtext-iconv-perl (1.7-5build6) ...
# Setting up llvm-6.0 (1:6.0-1ubuntu2) ...
# Setting up netcat (1.10-41.1) ...
# Setting up libcdr-0.1-1:amd64 (0.1.4-1build1) ...
# Setting up libpotrace0 (1.14-2) ...
# Setting up libgslcblas0:amd64 (2.4+dfsg-6) ...
# Setting up libsigc++-2.0-0v5:amd64 (2.10.0-2) ...
# Setting up fonts-lmodern (2.004.5-3) ...
# Setting up libcairomm-1.0-1v5:amd64 (1.12.2-3) ...
# Setting up libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# Setting up libmagickcore-6.q16-3:amd64 (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Setting up libgsl23:amd64 (2.4+dfsg-6) ...
# Setting up dictionaries-common (1.27.2) ...
# Setting up libvisio-0.1-1:amd64 (0.1.6-1build1) ...
# Setting up libwpd-0.10-10:amd64 (0.10.2-2) ...
# Setting up llvm (1:6.0-41~exp5~ubuntu1) ...
# Setting up llvm-6.0-dev (1:6.0-1ubuntu2) ...
# Setting up llvm-dev (1:6.0-41~exp5~ubuntu1) ...
# Setting up libmagickwand-6.q16-3:amd64 (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Setting up libglibmm-2.4-1v5:amd64 (2.56.0-1) ...
# Setting up libwpg-0.3-3:amd64 (0.3.1-3) ...
# Setting up aspell (0.60.7~20110707-4ubuntu0.2) ...
# Setting up lmodern (2.004.5-3) ...
# Setting up libatkmm-1.6-1v5:amd64 (2.24.2-3) ...
# Setting up libpangomm-1.4-1v5:amd64 (2.40.1-4) ...
# Setting up libgtkmm-2.4-1v5:amd64 (1:2.24.5-2) ...
# Setting up libmagick++-6.q16-7:amd64 (8:6.9.7.4+dfsg-16ubuntu6.11) ...
# Setting up aspell-en (2017.08.24-0-0.1) ...
# Setting up libenchant1c2a:amd64 (1.6.0-11.1) ...
# Setting up libgtkspell0:amd64 (2.0.16-1.2) ...
# Setting up inkscape (0.92.3-1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for systemd (237-3ubuntu10.52) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Processing triggers for dictionaries-common (1.27.2) ...
# aspell-autobuildhash: processing: en [en-common].
# aspell-autobuildhash: processing: en [en-variant_0].
# aspell-autobuildhash: processing: en [en-variant_1].
# aspell-autobuildhash: processing: en [en-variant_2].
# aspell-autobuildhash: processing: en [en-w_accents-only].
# aspell-autobuildhash: processing: en [en-wo_accents-only].
# aspell-autobuildhash: processing: en [en_AU-variant_0].
# aspell-autobuildhash: processing: en [en_AU-variant_1].
# aspell-autobuildhash: processing: en [en_AU-w_accents-only].
# aspell-autobuildhash: processing: en [en_AU-wo_accents-only].
# aspell-autobuildhash: processing: en [en_CA-variant_0].
# aspell-autobuildhash: processing: en [en_CA-variant_1].
# aspell-autobuildhash: processing: en [en_CA-w_accents-only].
# aspell-autobuildhash: processing: en [en_CA-wo_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ise-w_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ise-wo_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ize-w_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ize-wo_accents-only].
# aspell-autobuildhash: processing: en [en_GB-variant_0].
# aspell-autobuildhash: processing: en [en_GB-variant_1].
# aspell-autobuildhash: processing: en [en_US-w_accents-only].
# aspell-autobuildhash: processing: en [en_US-wo_accents-only].
# Processing triggers for tex-common (6.09) ...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# libglu1-mesa-dev is already the newest version (9.0.0-2.1build1).
# libglu1-mesa-dev set to manually installed.
# The following additional packages will be installed:
#   binutils-common binutils-x86-64-linux-gnu comerr-dev krb5-multidev
#   libavahi-client-dev libavahi-common-dev libavahi-compat-libdnssd1
#   libbinutils libcfitsio5 libdbus-1-dev libfftw3-bin libfftw3-long3
#   libfftw3-quad3 libfftw3-single3 libftgl2 libglew2.0 libgssrpc4
#   libgvc6-plugins-gtk libkadm5clnt-mit11 libkadm5srv-mit11 libkdb5-9
#   libldap-2.4-2 libldap-common libxdot4
# Suggested packages:
#   binutils-doc doc-base krb5-doc libfftw3-doc glew-utils krb5-user
# Recommended packages:
#   libnss-mdns libcfitsio-doc
# The following NEW packages will be installed:
#   comerr-dev krb5-multidev libavahi-client-dev libavahi-common-dev
#   libavahi-compat-libdnssd-dev libavahi-compat-libdnssd1 libcfitsio-dev
#   libcfitsio5 libdbus-1-dev libfftw3-bin libfftw3-dev libfftw3-long3
#   libfftw3-quad3 libfftw3-single3 libftgl-dev libftgl2 libglew-dev libglew2.0
#   libgraphviz-dev libgsl-dev libgssrpc4 libgvc6-plugins-gtk libkadm5clnt-mit11
#   libkadm5srv-mit11 libkdb5-9 libkrb5-dev libldap2-dev libxdot4 libxpm-dev
# The following packages will be upgraded:
#   binutils binutils-common binutils-x86-64-linux-gnu libbinutils libldap-2.4-2
#   libldap-common
# 6 upgraded, 29 newly installed, 0 to remove and 32 not upgraded.
# Need to get 10.6 MB of archives.
# After this operation, 42.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 binutils-x86-64-linux-gnu amd64 2.30-21ubuntu1~18.04.5 [1,839 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 binutils-common amd64 2.30-21ubuntu1~18.04.5 [197 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 binutils amd64 2.30-21ubuntu1~18.04.5 [3,388 B]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libbinutils amd64 2.30-21ubuntu1~18.04.5 [489 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgssrpc4 amd64 1.16-2ubuntu0.2 [54.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libkdb5-9 amd64 1.16-2ubuntu0.2 [37.3 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libkadm5srv-mit11 amd64 1.16-2ubuntu0.2 [49.7 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libkadm5clnt-mit11 amd64 1.16-2ubuntu0.2 [38.0 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 comerr-dev amd64 2.1-1.44.1-1ubuntu1.3 [38.5 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 krb5-multidev amd64 1.16-2ubuntu0.2 [120 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libavahi-common-dev amd64 0.7-3.1ubuntu1.3 [36.8 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdbus-1-dev amd64 1.12.2-1ubuntu1.2 [165 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libavahi-client-dev amd64 0.7-3.1ubuntu1.3 [31.0 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libavahi-compat-libdnssd1 amd64 0.7-3.1ubuntu1.3 [16.5 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libavahi-compat-libdnssd-dev amd64 0.7-3.1ubuntu1.3 [31.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libcfitsio5 amd64 3.430-2 [446 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libcfitsio-dev amd64 3.430-2 [494 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfftw3-long3 amd64 3.3.7-1 [308 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfftw3-quad3 amd64 3.3.7-1 [552 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfftw3-single3 amd64 3.3.7-1 [764 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfftw3-bin amd64 3.3.7-1 [32.7 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfftw3-dev amd64 3.3.7-1 [2,108 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libftgl2 amd64 2.1.3~rc5-4+nmu1.2 [56.5 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libftgl-dev amd64 2.1.3~rc5-4+nmu1.2 [830 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libglew2.0 amd64 2.0.0-5 [140 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libglew-dev amd64 2.0.0-5 [120 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libxdot4 amd64 2.40.1-2 [15.7 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgvc6-plugins-gtk amd64 2.40.1-2 [18.2 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgraphviz-dev amd64 2.40.1-2 [57.3 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgsl-dev amd64 2.4+dfsg-6 [1,023 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libldap-common all 2.4.45+dfsg-1ubuntu1.10 [15.8 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libldap-2.4-2 amd64 2.4.45+dfsg-1ubuntu1.10 [154 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxpm-dev amd64 1:3.5.12-1 [87.4 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libkrb5-dev amd64 1.16-2ubuntu0.2 [11.7 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libldap2-dev amd64 2.4.45+dfsg-1ubuntu1.10 [261 kB]
# Fetched 10.6 MB in 2s (4,662 kB/s)
# (Reading database ... 159989 files and directories currently installed.)
# Preparing to unpack .../00-binutils-x86-64-linux-gnu_2.30-21ubuntu1~18.04.5_amd64.deb ...
# Unpacking binutils-x86-64-linux-gnu (2.30-21ubuntu1~18.04.5) over (2.30-21ubuntu1~18.04.4) ...
# Preparing to unpack .../01-binutils-common_2.30-21ubuntu1~18.04.5_amd64.deb ...
# Unpacking binutils-common:amd64 (2.30-21ubuntu1~18.04.5) over (2.30-21ubuntu1~18.04.4) ...
# Preparing to unpack .../02-binutils_2.30-21ubuntu1~18.04.5_amd64.deb ...
# Unpacking binutils (2.30-21ubuntu1~18.04.5) over (2.30-21ubuntu1~18.04.4) ...
# Preparing to unpack .../03-libbinutils_2.30-21ubuntu1~18.04.5_amd64.deb ...
# Unpacking libbinutils:amd64 (2.30-21ubuntu1~18.04.5) over (2.30-21ubuntu1~18.04.4) ...
# Selecting previously unselected package libgssrpc4:amd64.
# Preparing to unpack .../04-libgssrpc4_1.16-2ubuntu0.2_amd64.deb ...
# Unpacking libgssrpc4:amd64 (1.16-2ubuntu0.2) ...
# Selecting previously unselected package libkdb5-9:amd64.
# Preparing to unpack .../05-libkdb5-9_1.16-2ubuntu0.2_amd64.deb ...
# Unpacking libkdb5-9:amd64 (1.16-2ubuntu0.2) ...
# Selecting previously unselected package libkadm5srv-mit11:amd64.
# Preparing to unpack .../06-libkadm5srv-mit11_1.16-2ubuntu0.2_amd64.deb ...
# Unpacking libkadm5srv-mit11:amd64 (1.16-2ubuntu0.2) ...
# Selecting previously unselected package libkadm5clnt-mit11:amd64.
# Preparing to unpack .../07-libkadm5clnt-mit11_1.16-2ubuntu0.2_amd64.deb ...
# Unpacking libkadm5clnt-mit11:amd64 (1.16-2ubuntu0.2) ...
# Selecting previously unselected package comerr-dev:amd64.
# Preparing to unpack .../08-comerr-dev_2.1-1.44.1-1ubuntu1.3_amd64.deb ...
# Unpacking comerr-dev:amd64 (2.1-1.44.1-1ubuntu1.3) ...
# Selecting previously unselected package krb5-multidev:amd64.
# Preparing to unpack .../09-krb5-multidev_1.16-2ubuntu0.2_amd64.deb ...
# Unpacking krb5-multidev:amd64 (1.16-2ubuntu0.2) ...
# Selecting previously unselected package libavahi-common-dev:amd64.
# Preparing to unpack .../10-libavahi-common-dev_0.7-3.1ubuntu1.3_amd64.deb ...
# Unpacking libavahi-common-dev:amd64 (0.7-3.1ubuntu1.3) ...
# Selecting previously unselected package libdbus-1-dev:amd64.
# Preparing to unpack .../11-libdbus-1-dev_1.12.2-1ubuntu1.2_amd64.deb ...
# Unpacking libdbus-1-dev:amd64 (1.12.2-1ubuntu1.2) ...
# Selecting previously unselected package libavahi-client-dev:amd64.
# Preparing to unpack .../12-libavahi-client-dev_0.7-3.1ubuntu1.3_amd64.deb ...
# Unpacking libavahi-client-dev:amd64 (0.7-3.1ubuntu1.3) ...
# Selecting previously unselected package libavahi-compat-libdnssd1:amd64.
# Preparing to unpack .../13-libavahi-compat-libdnssd1_0.7-3.1ubuntu1.3_amd64.deb ...
# Unpacking libavahi-compat-libdnssd1:amd64 (0.7-3.1ubuntu1.3) ...
# Selecting previously unselected package libavahi-compat-libdnssd-dev:amd64.
# Preparing to unpack .../14-libavahi-compat-libdnssd-dev_0.7-3.1ubuntu1.3_amd64.deb ...
# Unpacking libavahi-compat-libdnssd-dev:amd64 (0.7-3.1ubuntu1.3) ...
# Selecting previously unselected package libcfitsio5:amd64.
# Preparing to unpack .../15-libcfitsio5_3.430-2_amd64.deb ...
# Unpacking libcfitsio5:amd64 (3.430-2) ...
# Selecting previously unselected package libcfitsio-dev:amd64.
# Preparing to unpack .../16-libcfitsio-dev_3.430-2_amd64.deb ...
# Unpacking libcfitsio-dev:amd64 (3.430-2) ...
# Selecting previously unselected package libfftw3-long3:amd64.
# Preparing to unpack .../17-libfftw3-long3_3.3.7-1_amd64.deb ...
# Unpacking libfftw3-long3:amd64 (3.3.7-1) ...
# Selecting previously unselected package libfftw3-quad3:amd64.
# Preparing to unpack .../18-libfftw3-quad3_3.3.7-1_amd64.deb ...
# Unpacking libfftw3-quad3:amd64 (3.3.7-1) ...
# Selecting previously unselected package libfftw3-single3:amd64.
# Preparing to unpack .../19-libfftw3-single3_3.3.7-1_amd64.deb ...
# Unpacking libfftw3-single3:amd64 (3.3.7-1) ...
# Selecting previously unselected package libfftw3-bin.
# Preparing to unpack .../20-libfftw3-bin_3.3.7-1_amd64.deb ...
# Unpacking libfftw3-bin (3.3.7-1) ...
# Selecting previously unselected package libfftw3-dev:amd64.
# Preparing to unpack .../21-libfftw3-dev_3.3.7-1_amd64.deb ...
# Unpacking libfftw3-dev:amd64 (3.3.7-1) ...
# Selecting previously unselected package libftgl2:amd64.
# Preparing to unpack .../22-libftgl2_2.1.3~rc5-4+nmu1.2_amd64.deb ...
# Unpacking libftgl2:amd64 (2.1.3~rc5-4+nmu1.2) ...
# Selecting previously unselected package libftgl-dev.
# Preparing to unpack .../23-libftgl-dev_2.1.3~rc5-4+nmu1.2_amd64.deb ...
# Unpacking libftgl-dev (2.1.3~rc5-4+nmu1.2) ...
# Selecting previously unselected package libglew2.0:amd64.
# Preparing to unpack .../24-libglew2.0_2.0.0-5_amd64.deb ...
# Unpacking libglew2.0:amd64 (2.0.0-5) ...
# Selecting previously unselected package libglew-dev:amd64.
# Preparing to unpack .../25-libglew-dev_2.0.0-5_amd64.deb ...
# Unpacking libglew-dev:amd64 (2.0.0-5) ...
# Selecting previously unselected package libxdot4.
# Preparing to unpack .../26-libxdot4_2.40.1-2_amd64.deb ...
# Unpacking libxdot4 (2.40.1-2) ...
# Selecting previously unselected package libgvc6-plugins-gtk.
# Preparing to unpack .../27-libgvc6-plugins-gtk_2.40.1-2_amd64.deb ...
# Unpacking libgvc6-plugins-gtk (2.40.1-2) ...
# Selecting previously unselected package libgraphviz-dev.
# Preparing to unpack .../28-libgraphviz-dev_2.40.1-2_amd64.deb ...
# Unpacking libgraphviz-dev (2.40.1-2) ...
# Selecting previously unselected package libgsl-dev.
# Preparing to unpack .../29-libgsl-dev_2.4+dfsg-6_amd64.deb ...
# Unpacking libgsl-dev (2.4+dfsg-6) ...
# Preparing to unpack .../30-libldap-common_2.4.45+dfsg-1ubuntu1.10_all.deb ...
# Unpacking libldap-common (2.4.45+dfsg-1ubuntu1.10) over (2.4.45+dfsg-1ubuntu1.8) ...
# Preparing to unpack .../31-libldap-2.4-2_2.4.45+dfsg-1ubuntu1.10_amd64.deb ...
# Unpacking libldap-2.4-2:amd64 (2.4.45+dfsg-1ubuntu1.10) over (2.4.45+dfsg-1ubuntu1.8) ...
# Selecting previously unselected package libxpm-dev:amd64.
# Preparing to unpack .../32-libxpm-dev_1%3a3.5.12-1_amd64.deb ...
# Unpacking libxpm-dev:amd64 (1:3.5.12-1) ...
# Selecting previously unselected package libkrb5-dev:amd64.
# Preparing to unpack .../33-libkrb5-dev_1.16-2ubuntu0.2_amd64.deb ...
# Unpacking libkrb5-dev:amd64 (1.16-2ubuntu0.2) ...
# Selecting previously unselected package libldap2-dev:amd64.
# Preparing to unpack .../34-libldap2-dev_2.4.45+dfsg-1ubuntu1.10_amd64.deb ...
# Unpacking libldap2-dev:amd64 (2.4.45+dfsg-1ubuntu1.10) ...
# Setting up libcfitsio5:amd64 (3.430-2) ...
# Setting up libdbus-1-dev:amd64 (1.12.2-1ubuntu1.2) ...
# Setting up libcfitsio-dev:amd64 (3.430-2) ...
# Setting up libgssrpc4:amd64 (1.16-2ubuntu0.2) ...
# Setting up libxdot4 (2.40.1-2) ...
# Setting up comerr-dev:amd64 (2.1-1.44.1-1ubuntu1.3) ...
# Setting up libgsl-dev (2.4+dfsg-6) ...
# Setting up libldap-common (2.4.45+dfsg-1ubuntu1.10) ...
# Setting up libxpm-dev:amd64 (1:3.5.12-1) ...
# Setting up libftgl2:amd64 (2.1.3~rc5-4+nmu1.2) ...
# Setting up libavahi-common-dev:amd64 (0.7-3.1ubuntu1.3) ...
# Setting up libavahi-client-dev:amd64 (0.7-3.1ubuntu1.3) ...
# Setting up libavahi-compat-libdnssd1:amd64 (0.7-3.1ubuntu1.3) ...
# Setting up libgvc6-plugins-gtk (2.40.1-2) ...
# Setting up libkdb5-9:amd64 (1.16-2ubuntu0.2) ...
# Setting up libgraphviz-dev (2.40.1-2) ...
# Setting up libfftw3-quad3:amd64 (3.3.7-1) ...
# Setting up binutils-common:amd64 (2.30-21ubuntu1~18.04.5) ...
# Setting up libldap-2.4-2:amd64 (2.4.45+dfsg-1ubuntu1.10) ...
# Setting up libkadm5srv-mit11:amd64 (1.16-2ubuntu0.2) ...
# Setting up libglew2.0:amd64 (2.0.0-5) ...
# Setting up libfftw3-single3:amd64 (3.3.7-1) ...
# Setting up libkadm5clnt-mit11:amd64 (1.16-2ubuntu0.2) ...
# Setting up libfftw3-long3:amd64 (3.3.7-1) ...
# Setting up libglew-dev:amd64 (2.0.0-5) ...
# Setting up libldap2-dev:amd64 (2.4.45+dfsg-1ubuntu1.10) ...
# Setting up libfftw3-bin (3.3.7-1) ...
# Setting up libftgl-dev (2.1.3~rc5-4+nmu1.2) ...
# Setting up libbinutils:amd64 (2.30-21ubuntu1~18.04.5) ...
# Setting up libavahi-compat-libdnssd-dev:amd64 (0.7-3.1ubuntu1.3) ...
# Setting up krb5-multidev:amd64 (1.16-2ubuntu0.2) ...
# Setting up libfftw3-dev:amd64 (3.3.7-1) ...
# Setting up binutils-x86-64-linux-gnu (2.30-21ubuntu1~18.04.5) ...
# Setting up libkrb5-dev:amd64 (1.16-2ubuntu0.2) ...
# Setting up binutils (2.30-21ubuntu1~18.04.5) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# root/
# root/LICENSE
# root/README/
# root/README/CREDITS
# root/README/DEVELOPMENT.md
# root/README/INSTALL
# root/README/README.ALIEN
# root/README/README.AUTH
# root/README/README.CXXMODULES.md
# root/README/README.MONALISA
# root/README/README.SELECTOR
# root/README/ReleaseNotes/
# root/README/ReleaseNotes/empty.md
# root/README/ReleaseNotes/old/
# root/README/ReleaseNotes/old/ChangeLog-2-24
# root/README/ReleaseNotes/v604/
# root/README/ReleaseNotes/v604/colz0.png
# root/README/ReleaseNotes/v604/index.md
# root/README/ReleaseNotes/v604/nostackb.png
# root/README/ReleaseNotes/v604/palette_100.png
# root/README/ReleaseNotes/v604/palette_101.png
# root/README/ReleaseNotes/v604/palette_102.png
# root/README/ReleaseNotes/v604/palette_103.png
# root/README/ReleaseNotes/v604/palette_104.png
# root/README/ReleaseNotes/v604/palette_105.png
# root/README/ReleaseNotes/v604/palette_106.png
# root/README/ReleaseNotes/v604/palette_107.png
# root/README/ReleaseNotes/v604/palette_108.png
# root/README/ReleaseNotes/v604/palette_109.png
# root/README/ReleaseNotes/v604/palette_110.png
# root/README/ReleaseNotes/v604/palette_111.png
# root/README/ReleaseNotes/v604/palette_51.png
# root/README/ReleaseNotes/v604/palette_52.png
# root/README/ReleaseNotes/v604/palette_53.png
# root/README/ReleaseNotes/v604/palette_54.png
# root/README/ReleaseNotes/v604/palette_55.png
# root/README/ReleaseNotes/v604/palette_56.png
# root/README/ReleaseNotes/v604/palette_57.png
# root/README/ReleaseNotes/v604/palette_58.png
# root/README/ReleaseNotes/v604/palette_59.png
# root/README/ReleaseNotes/v604/palette_60.png
# root/README/ReleaseNotes/v604/palette_61.png
# root/README/ReleaseNotes/v604/palette_62.png
# root/README/ReleaseNotes/v604/palette_63.png
# root/README/ReleaseNotes/v604/palette_64.png
# root/README/ReleaseNotes/v604/palette_65.png
# root/README/ReleaseNotes/v604/palette_66.png
# root/README/ReleaseNotes/v604/palette_67.png
# root/README/ReleaseNotes/v604/palette_68.png
# root/README/ReleaseNotes/v604/palette_69.png
# root/README/ReleaseNotes/v604/palette_70.png
# root/README/ReleaseNotes/v604/palette_71.png
# root/README/ReleaseNotes/v604/palette_72.png
# root/README/ReleaseNotes/v604/palette_73.png
# root/README/ReleaseNotes/v604/palette_74.png
# root/README/ReleaseNotes/v604/palette_75.png
# root/README/ReleaseNotes/v604/palette_76.png
# root/README/ReleaseNotes/v604/palette_77.png
# root/README/ReleaseNotes/v604/palette_78.png
# root/README/ReleaseNotes/v604/palette_79.png
# root/README/ReleaseNotes/v604/palette_80.png
# root/README/ReleaseNotes/v604/palette_81.png
# root/README/ReleaseNotes/v604/palette_82.png
# root/README/ReleaseNotes/v604/palette_83.png
# root/README/ReleaseNotes/v604/palette_84.png
# root/README/ReleaseNotes/v604/palette_85.png
# root/README/ReleaseNotes/v604/palette_86.png
# root/README/ReleaseNotes/v604/palette_87.png
# root/README/ReleaseNotes/v604/palette_88.png
# root/README/ReleaseNotes/v604/palette_89.png
# root/README/ReleaseNotes/v604/palette_90.png
# root/README/ReleaseNotes/v604/palette_91.png
# root/README/ReleaseNotes/v604/palette_92.png
# root/README/ReleaseNotes/v604/palette_93.png
# root/README/ReleaseNotes/v604/palette_94.png
# root/README/ReleaseNotes/v604/palette_95.png
# root/README/ReleaseNotes/v604/palette_96.png
# root/README/ReleaseNotes/v604/palette_97.png
# root/README/ReleaseNotes/v604/palette_98.png
# root/README/ReleaseNotes/v604/palette_99.png
# root/README/ReleaseNotes/v606/
# root/README/ReleaseNotes/v606/index.md
# root/README/ReleaseNotes/v606/palette_112.png
# root/README/ReleaseNotes/v606/ttree_makeselector_option_examples.png
# root/README/ReleaseNotes/v608/
# root/README/ReleaseNotes/v608/index.md
# root/README/ReleaseNotes/v610/
# root/README/ReleaseNotes/v610/NewBoxOption.png
# root/README/ReleaseNotes/v610/NewMarkers.png
# root/README/ReleaseNotes/v610/ReverseAxis.png
# root/README/ReleaseNotes/v610/index.md
# root/README/ReleaseNotes/v612/
# root/README/ReleaseNotes/v612/index.md
# root/README/ReleaseNotes/v614/
# root/README/ReleaseNotes/v614/index.md
# root/README/ReleaseNotes/v616/
# root/README/ReleaseNotes/v616/index.md
# root/README/ReleaseNotes/v618/
# root/README/ReleaseNotes/v618/index.md
# root/README/ReleaseNotes/v620/
# root/README/ReleaseNotes/v620/index.md
# root/README/ReleaseNotes/v622/
# root/README/ReleaseNotes/v622/index.md
# root/README/ReleaseNotes/v624/
# root/README/ReleaseNotes/v624/index.md
# root/README/cfortran.doc
# root/bin/
# root/bin/genreflex
# root/bin/hadd
# root/bin/hist2workspace
# root/bin/memprobe
# root/bin/prepareHistFactory
# root/bin/proofserv
# root/bin/proofserv.exe
# root/bin/rmkdepend
# root/bin/root
# root/bin/root-config
# root/bin/root.exe
# root/bin/rootbrowse
# root/bin/rootcint
# root/bin/rootcling
# root/bin/rootcp
# root/bin/rootdrawtree
# root/bin/rooteventselector
# root/bin/rootls
# root/bin/rootmkdir
# root/bin/rootmv
# root/bin/rootn.exe
# root/bin/rootnb.exe
# root/bin/rootprint
# root/bin/rootrm
# root/bin/roots
# root/bin/roots.exe
# root/bin/rootslimtree
# root/bin/setxrd.csh
# root/bin/setxrd.sh
# root/bin/thisroot.csh
# root/bin/thisroot.fish
# root/bin/thisroot.sh
# root/bin/xpdtest
# root/cmake/
# root/cmake/ROOTConfig-targets-release.cmake
# root/cmake/ROOTConfig-targets.cmake
# root/cmake/ROOTConfig-version.cmake
# root/cmake/ROOTConfig.cmake
# root/cmake/ROOTUseFile.cmake
# root/cmake/RootMacros.cmake
# root/cmake/RootTestDriver.cmake
# root/config/
# root/config/Makefile.comp
# root/config/Makefile.config
# root/emacs/
# root/emacs/site-lisp/
# root/emacs/site-lisp/root-help.el
# root/etc/
# root/etc/HistFactorySchema.dtd
# root/etc/Makefile.arch
# root/etc/RadioNuclides.txt
# root/etc/class.rules
# root/etc/cling/
# root/etc/cling/Interpreter/
# root/etc/cling/Interpreter/DynamicExprInfo.h
# root/etc/cling/Interpreter/DynamicLookupLifetimeHandler.h
# root/etc/cling/Interpreter/DynamicLookupRuntimeUniverse.h
# root/etc/cling/Interpreter/Exception.h
# root/etc/cling/Interpreter/RuntimeOptions.h
# root/etc/cling/Interpreter/RuntimePrintValue.h
# root/etc/cling/Interpreter/RuntimeUniverse.h
# root/etc/cling/Interpreter/Value.h
# root/etc/cling/Interpreter/Visibility.h
# root/etc/cling/boost.modulemap
# root/etc/cling/cint/
# root/etc/cling/cint/multimap
# root/etc/cling/cint/multiset
# root/etc/cling/cuda.modulemap
# root/etc/cling/lib/
# root/etc/cling/lib/clang/
# root/etc/cling/lib/clang/9.0.1/
# root/etc/cling/lib/clang/9.0.1/include/
# root/etc/cling/lib/clang/9.0.1/include/__clang_cuda_builtin_vars.h
# root/etc/cling/lib/clang/9.0.1/include/__clang_cuda_cmath.h
# root/etc/cling/lib/clang/9.0.1/include/__clang_cuda_complex_builtins.h
# root/etc/cling/lib/clang/9.0.1/include/__clang_cuda_device_functions.h
# root/etc/cling/lib/clang/9.0.1/include/__clang_cuda_intrinsics.h
# root/etc/cling/lib/clang/9.0.1/include/__clang_cuda_libdevice_declares.h
# root/etc/cling/lib/clang/9.0.1/include/__clang_cuda_math_forward_declares.h
# root/etc/cling/lib/clang/9.0.1/include/__clang_cuda_runtime_wrapper.h
# root/etc/cling/lib/clang/9.0.1/include/__stddef_max_align_t.h
# root/etc/cling/lib/clang/9.0.1/include/__wmmintrin_aes.h
# root/etc/cling/lib/clang/9.0.1/include/__wmmintrin_pclmul.h
# root/etc/cling/lib/clang/9.0.1/include/adxintrin.h
# root/etc/cling/lib/clang/9.0.1/include/altivec.h
# root/etc/cling/lib/clang/9.0.1/include/ammintrin.h
# root/etc/cling/lib/clang/9.0.1/include/arm64intr.h
# root/etc/cling/lib/clang/9.0.1/include/arm_acle.h
# root/etc/cling/lib/clang/9.0.1/include/arm_fp16.h
# root/etc/cling/lib/clang/9.0.1/include/arm_neon.h
# root/etc/cling/lib/clang/9.0.1/include/armintr.h
# root/etc/cling/lib/clang/9.0.1/include/assert.h
# root/etc/cling/lib/clang/9.0.1/include/avx2intrin.h
# root/etc/cling/lib/clang/9.0.1/include/avx512bf16intrin.h
# root/etc/cling/lib/clang/9.0.1/include/avx512bitalgintrin.h
# root/etc/cling/lib/clang/9.0.1/include/avx512bwintrin.h
# root/etc/cling/lib/clang/9.0.1/include/avx512cdintrin.h
# root/etc/cling/lib/clang/9.0.1/include/avx512dqintrin.h
# root/etc/cling/lib/clang/9.0.1/include/avx512erintrin.h
# root/etc/cling/lib/clang/9.0.1/include/avx512fintrin.h
# root/etc/cling/lib/clang/9.0.1/include/avx512ifmaintrin.h
# root/etc/cling/lib/clang/9.0.1/include/avx512ifmavlintrin.h
# root/etc/cling/lib/clang/9.0.1/include/avx512pfintrin.h
# root/etc/cling/lib/clang/9.0.1/include/avx512vbmi2intrin.h
# root/etc/cling/lib/clang/9.0.1/include/avx512vbmiintrin.h
# root/etc/cling/lib/clang/9.0.1/include/avx512vbmivlintrin.h
# root/etc/cling/lib/clang/9.0.1/include/avx512vlbf16intrin.h
# root/etc/cling/lib/clang/9.0.1/include/avx512vlbitalgintrin.h
# root/etc/cling/lib/clang/9.0.1/include/avx512vlbwintrin.h
# root/etc/cling/lib/clang/9.0.1/include/avx512vlcdintrin.h
# root/etc/cling/lib/clang/9.0.1/include/avx512vldqintrin.h
# root/etc/cling/lib/clang/9.0.1/include/avx512vlintrin.h
# root/etc/cling/lib/clang/9.0.1/include/avx512vlvbmi2intrin.h
# root/etc/cling/lib/clang/9.0.1/include/avx512vlvnniintrin.h
# root/etc/cling/lib/clang/9.0.1/include/avx512vlvp2intersectintrin.h
# root/etc/cling/lib/clang/9.0.1/include/avx512vnniintrin.h
# root/etc/cling/lib/clang/9.0.1/include/avx512vp2intersectintrin.h
# root/etc/cling/lib/clang/9.0.1/include/avx512vpopcntdqintrin.h
# root/etc/cling/lib/clang/9.0.1/include/avx512vpopcntdqvlintrin.h
# root/etc/cling/lib/clang/9.0.1/include/avxintrin.h
# root/etc/cling/lib/clang/9.0.1/include/bmi2intrin.h
# root/etc/cling/lib/clang/9.0.1/include/bmiintrin.h
# root/etc/cling/lib/clang/9.0.1/include/cetintrin.h
# root/etc/cling/lib/clang/9.0.1/include/cldemoteintrin.h
# root/etc/cling/lib/clang/9.0.1/include/clflushoptintrin.h
# root/etc/cling/lib/clang/9.0.1/include/clwbintrin.h
# root/etc/cling/lib/clang/9.0.1/include/clzerointrin.h
# root/etc/cling/lib/clang/9.0.1/include/cpuid.h
# root/etc/cling/lib/clang/9.0.1/include/cuda_wrappers/
# root/etc/cling/lib/clang/9.0.1/include/cuda_wrappers/algorithm
# root/etc/cling/lib/clang/9.0.1/include/cuda_wrappers/complex
# root/etc/cling/lib/clang/9.0.1/include/cuda_wrappers/new
# root/etc/cling/lib/clang/9.0.1/include/emmintrin.h
# root/etc/cling/lib/clang/9.0.1/include/enqcmdintrin.h
# root/etc/cling/lib/clang/9.0.1/include/f16cintrin.h
# root/etc/cling/lib/clang/9.0.1/include/float.h
# root/etc/cling/lib/clang/9.0.1/include/fma4intrin.h
# root/etc/cling/lib/clang/9.0.1/include/fmaintrin.h
# root/etc/cling/lib/clang/9.0.1/include/fxsrintrin.h
# root/etc/cling/lib/clang/9.0.1/include/gfniintrin.h
# root/etc/cling/lib/clang/9.0.1/include/htmintrin.h
# root/etc/cling/lib/clang/9.0.1/include/htmxlintrin.h
# root/etc/cling/lib/clang/9.0.1/include/ia32intrin.h
# root/etc/cling/lib/clang/9.0.1/include/immintrin.h
# root/etc/cling/lib/clang/9.0.1/include/intrin.h
# root/etc/cling/lib/clang/9.0.1/include/inttypes.h
# root/etc/cling/lib/clang/9.0.1/include/invpcidintrin.h
# root/etc/cling/lib/clang/9.0.1/include/iso646.h
# root/etc/cling/lib/clang/9.0.1/include/limits.h
# root/etc/cling/lib/clang/9.0.1/include/lwpintrin.h
# root/etc/cling/lib/clang/9.0.1/include/lzcntintrin.h
# root/etc/cling/lib/clang/9.0.1/include/mm3dnow.h
# root/etc/cling/lib/clang/9.0.1/include/mm_malloc.h
# root/etc/cling/lib/clang/9.0.1/include/mmintrin.h
# root/etc/cling/lib/clang/9.0.1/include/module.modulemap
# root/etc/cling/lib/clang/9.0.1/include/movdirintrin.h
# root/etc/cling/lib/clang/9.0.1/include/msa.h
# root/etc/cling/lib/clang/9.0.1/include/mwaitxintrin.h
# root/etc/cling/lib/clang/9.0.1/include/nmmintrin.h
# root/etc/cling/lib/clang/9.0.1/include/opencl-c-base.h
# root/etc/cling/lib/clang/9.0.1/include/opencl-c.h
# root/etc/cling/lib/clang/9.0.1/include/openmp_wrappers/
# root/etc/cling/lib/clang/9.0.1/include/openmp_wrappers/__clang_openmp_math.h
# root/etc/cling/lib/clang/9.0.1/include/openmp_wrappers/__clang_openmp_math_declares.h
# root/etc/cling/lib/clang/9.0.1/include/openmp_wrappers/cmath
# root/etc/cling/lib/clang/9.0.1/include/openmp_wrappers/math.h
# root/etc/cling/lib/clang/9.0.1/include/pconfigintrin.h
# root/etc/cling/lib/clang/9.0.1/include/pkuintrin.h
# root/etc/cling/lib/clang/9.0.1/include/pmmintrin.h
# root/etc/cling/lib/clang/9.0.1/include/popcntintrin.h
# root/etc/cling/lib/clang/9.0.1/include/ppc_wrappers/
# root/etc/cling/lib/clang/9.0.1/include/ppc_wrappers/emmintrin.h
# root/etc/cling/lib/clang/9.0.1/include/ppc_wrappers/mm_malloc.h
# ...
# root/ui5/distribution/resources/sap/ui/layout/themes/sap_fiori_3/.theming
# root/ui5/distribution/resources/sap/ui/layout/themes/sap_fiori_3/css_variables.css
# root/ui5/distribution/resources/sap/ui/layout/themes/sap_fiori_3/css_variables.less
# root/ui5/distribution/resources/sap/ui/layout/themes/sap_fiori_3/css_variables.source.less
# root/ui5/distribution/resources/sap/ui/layout/themes/sap_fiori_3/library-RTL.css
# root/ui5/distribution/resources/sap/ui/layout/themes/sap_fiori_3/library-parameters.json
# root/ui5/distribution/resources/sap/ui/layout/themes/sap_fiori_3/library.css
# root/ui5/distribution/resources/sap/ui/layout/themes/sap_fiori_3/library.less
# root/ui5/distribution/resources/sap/ui/layout/themes/sap_fiori_3/library.source.less
# root/ui5/distribution/resources/sap/ui/layout/themes/sap_fiori_3/library_skeleton-RTL.css
# root/ui5/distribution/resources/sap/ui/layout/themes/sap_fiori_3/library_skeleton.css
# root/ui5/distribution/resources/sap/ui/layout/themes/sap_fiori_3/resources.json
# root/ui5/distribution/resources/sap/ui/table/
# root/ui5/distribution/resources/sap/ui/table/library-preload.js
# root/ui5/distribution/resources/sap/ui/table/library-preload.js.map
# root/ui5/distribution/resources/sap/ui/table/messagebundle.properties
# root/ui5/distribution/resources/sap/ui/table/messagebundle_en.properties
# root/ui5/distribution/resources/sap/ui/table/themes/
# root/ui5/distribution/resources/sap/ui/table/themes/base/
# root/ui5/distribution/resources/sap/ui/table/themes/base/.theming
# root/ui5/distribution/resources/sap/ui/table/themes/base/css_variables.css
# root/ui5/distribution/resources/sap/ui/table/themes/base/css_variables.less
# root/ui5/distribution/resources/sap/ui/table/themes/base/css_variables.source.less
# root/ui5/distribution/resources/sap/ui/table/themes/base/library-RTL.css
# root/ui5/distribution/resources/sap/ui/table/themes/base/library-parameters.json
# root/ui5/distribution/resources/sap/ui/table/themes/base/library.css
# root/ui5/distribution/resources/sap/ui/table/themes/base/library.less
# root/ui5/distribution/resources/sap/ui/table/themes/base/library.source.less
# root/ui5/distribution/resources/sap/ui/table/themes/base/library_skeleton-RTL.css
# root/ui5/distribution/resources/sap/ui/table/themes/base/library_skeleton.css
# root/ui5/distribution/resources/sap/ui/table/themes/base/resources.json
# root/ui5/distribution/resources/sap/ui/table/themes/sap_belize/
# root/ui5/distribution/resources/sap/ui/table/themes/sap_belize/.theming
# root/ui5/distribution/resources/sap/ui/table/themes/sap_belize/css_variables.css
# root/ui5/distribution/resources/sap/ui/table/themes/sap_belize/css_variables.less
# root/ui5/distribution/resources/sap/ui/table/themes/sap_belize/css_variables.source.less
# root/ui5/distribution/resources/sap/ui/table/themes/sap_belize/library-RTL.css
# root/ui5/distribution/resources/sap/ui/table/themes/sap_belize/library-parameters.json
# root/ui5/distribution/resources/sap/ui/table/themes/sap_belize/library.css
# root/ui5/distribution/resources/sap/ui/table/themes/sap_belize/library.less
# root/ui5/distribution/resources/sap/ui/table/themes/sap_belize/library.source.less
# root/ui5/distribution/resources/sap/ui/table/themes/sap_belize/library_skeleton-RTL.css
# root/ui5/distribution/resources/sap/ui/table/themes/sap_belize/library_skeleton.css
# root/ui5/distribution/resources/sap/ui/table/themes/sap_belize/resources.json
# root/ui5/distribution/resources/sap/ui/table/themes/sap_fiori_3/
# root/ui5/distribution/resources/sap/ui/table/themes/sap_fiori_3/.theming
# root/ui5/distribution/resources/sap/ui/table/themes/sap_fiori_3/css_variables.css
# root/ui5/distribution/resources/sap/ui/table/themes/sap_fiori_3/css_variables.less
# root/ui5/distribution/resources/sap/ui/table/themes/sap_fiori_3/css_variables.source.less
# root/ui5/distribution/resources/sap/ui/table/themes/sap_fiori_3/library-RTL.css
# root/ui5/distribution/resources/sap/ui/table/themes/sap_fiori_3/library-parameters.json
# root/ui5/distribution/resources/sap/ui/table/themes/sap_fiori_3/library.css
# root/ui5/distribution/resources/sap/ui/table/themes/sap_fiori_3/library.less
# root/ui5/distribution/resources/sap/ui/table/themes/sap_fiori_3/library.source.less
# root/ui5/distribution/resources/sap/ui/table/themes/sap_fiori_3/library_skeleton-RTL.css
# root/ui5/distribution/resources/sap/ui/table/themes/sap_fiori_3/library_skeleton.css
# root/ui5/distribution/resources/sap/ui/table/themes/sap_fiori_3/resources.json
# root/ui5/distribution/resources/sap/ui/thirdparty/
# root/ui5/distribution/resources/sap/ui/thirdparty/jquery-compat.js
# root/ui5/distribution/resources/sap/ui/unified/
# root/ui5/distribution/resources/sap/ui/unified/img/
# root/ui5/distribution/resources/sap/ui/unified/img/ColorPicker/
# root/ui5/distribution/resources/sap/ui/unified/img/ColorPicker/Alphaslider_BG.png
# root/ui5/distribution/resources/sap/ui/unified/library-preload.js
# root/ui5/distribution/resources/sap/ui/unified/library-preload.js.map
# root/ui5/distribution/resources/sap/ui/unified/messagebundle.properties
# root/ui5/distribution/resources/sap/ui/unified/messagebundle_en.properties
# root/ui5/distribution/resources/sap/ui/unified/themes/
# root/ui5/distribution/resources/sap/ui/unified/themes/base/
# root/ui5/distribution/resources/sap/ui/unified/themes/base/.theming
# root/ui5/distribution/resources/sap/ui/unified/themes/base/css_variables.css
# root/ui5/distribution/resources/sap/ui/unified/themes/base/css_variables.less
# root/ui5/distribution/resources/sap/ui/unified/themes/base/css_variables.source.less
# root/ui5/distribution/resources/sap/ui/unified/themes/base/img/
# root/ui5/distribution/resources/sap/ui/unified/themes/base/img/ColorPicker/
# root/ui5/distribution/resources/sap/ui/unified/themes/base/img/ColorPicker/Alphaslider_BG.png
# root/ui5/distribution/resources/sap/ui/unified/themes/base/img/ColorPicker/ColorBar.png
# root/ui5/distribution/resources/sap/ui/unified/themes/base/img/ColorPicker/GradientBox.png
# root/ui5/distribution/resources/sap/ui/unified/themes/base/img/ColorPicker/PickingCursor-Default.png
# root/ui5/distribution/resources/sap/ui/unified/themes/base/img/ColorPicker/Swatch_BG.png
# root/ui5/distribution/resources/sap/ui/unified/themes/base/img/ColorPicker/Unified_Swatch_BG.png
# root/ui5/distribution/resources/sap/ui/unified/themes/base/img/create.txt
# root/ui5/distribution/resources/sap/ui/unified/themes/base/img-RTL/
# root/ui5/distribution/resources/sap/ui/unified/themes/base/img-RTL/ColorPicker/
# root/ui5/distribution/resources/sap/ui/unified/themes/base/img-RTL/ColorPicker/Alphaslider_BG.png
# root/ui5/distribution/resources/sap/ui/unified/themes/base/img-RTL/ColorPicker/ColorBar.png
# root/ui5/distribution/resources/sap/ui/unified/themes/base/img-RTL/ColorPicker/GradientBox.png
# root/ui5/distribution/resources/sap/ui/unified/themes/base/img-RTL/ColorPicker/PickingCursor-Default.png
# root/ui5/distribution/resources/sap/ui/unified/themes/base/img-RTL/ColorPicker/Swatch_BG.png
# root/ui5/distribution/resources/sap/ui/unified/themes/base/img-RTL/ColorPicker/Unified_Swatch_BG.png
# root/ui5/distribution/resources/sap/ui/unified/themes/base/img-RTL/create.txt
# root/ui5/distribution/resources/sap/ui/unified/themes/base/library-RTL.css
# root/ui5/distribution/resources/sap/ui/unified/themes/base/library-parameters.json
# root/ui5/distribution/resources/sap/ui/unified/themes/base/library.css
# root/ui5/distribution/resources/sap/ui/unified/themes/base/library.less
# root/ui5/distribution/resources/sap/ui/unified/themes/base/library.source.less
# root/ui5/distribution/resources/sap/ui/unified/themes/base/library_skeleton-RTL.css
# root/ui5/distribution/resources/sap/ui/unified/themes/base/library_skeleton.css
# root/ui5/distribution/resources/sap/ui/unified/themes/base/resources.json
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_belize/
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_belize/.theming
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_belize/ColorPicker/
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_belize/ColorPicker/Alphaslider_BG.png
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_belize/ColorPicker/Swatch_BG.png
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_belize/css_variables.css
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_belize/css_variables.less
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_belize/css_variables.source.less
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_belize/library-RTL.css
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_belize/library-parameters.json
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_belize/library.css
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_belize/library.less
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_belize/library.source.less
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_belize/library_skeleton-RTL.css
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_belize/library_skeleton.css
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_belize/resources.json
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_fiori_3/
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_fiori_3/.theming
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_fiori_3/ColorPicker/
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_fiori_3/ColorPicker/Alphaslider_BG.png
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_fiori_3/ColorPicker/Swatch_BG.png
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_fiori_3/css_variables.css
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_fiori_3/css_variables.less
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_fiori_3/css_variables.source.less
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_fiori_3/library-RTL.css
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_fiori_3/library-parameters.json
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_fiori_3/library.css
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_fiori_3/library.less
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_fiori_3/library.source.less
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_fiori_3/library_skeleton-RTL.css
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_fiori_3/library_skeleton.css
# root/ui5/distribution/resources/sap/ui/unified/themes/sap_fiori_3/resources.json
# root/ui5/distribution/resources/sap/uxap/
# root/ui5/distribution/resources/sap/uxap/library-preload.js
# root/ui5/distribution/resources/sap/uxap/library-preload.js.map
# root/ui5/distribution/resources/sap/uxap/messagebundle.properties
# root/ui5/distribution/resources/sap/uxap/messagebundle_en_US.properties
# root/ui5/distribution/resources/sap/uxap/themes/
# root/ui5/distribution/resources/sap/uxap/themes/base/
# root/ui5/distribution/resources/sap/uxap/themes/base/.theming
# root/ui5/distribution/resources/sap/uxap/themes/base/css_variables.css
# root/ui5/distribution/resources/sap/uxap/themes/base/css_variables.less
# root/ui5/distribution/resources/sap/uxap/themes/base/css_variables.source.less
# root/ui5/distribution/resources/sap/uxap/themes/base/library-RTL.css
# root/ui5/distribution/resources/sap/uxap/themes/base/library-parameters.json
# root/ui5/distribution/resources/sap/uxap/themes/base/library.css
# root/ui5/distribution/resources/sap/uxap/themes/base/library.less
# root/ui5/distribution/resources/sap/uxap/themes/base/library.source.less
# root/ui5/distribution/resources/sap/uxap/themes/base/library_skeleton-RTL.css
# root/ui5/distribution/resources/sap/uxap/themes/base/library_skeleton.css
# root/ui5/distribution/resources/sap/uxap/themes/base/resources.json
# root/ui5/distribution/resources/sap/uxap/themes/sap_belize/
# root/ui5/distribution/resources/sap/uxap/themes/sap_belize/.theming
# root/ui5/distribution/resources/sap/uxap/themes/sap_belize/css_variables.css
# root/ui5/distribution/resources/sap/uxap/themes/sap_belize/css_variables.less
# root/ui5/distribution/resources/sap/uxap/themes/sap_belize/css_variables.source.less
# root/ui5/distribution/resources/sap/uxap/themes/sap_belize/library-RTL.css
# root/ui5/distribution/resources/sap/uxap/themes/sap_belize/library-parameters.json
# root/ui5/distribution/resources/sap/uxap/themes/sap_belize/library.css
# root/ui5/distribution/resources/sap/uxap/themes/sap_belize/library.less
# root/ui5/distribution/resources/sap/uxap/themes/sap_belize/library.source.less
# root/ui5/distribution/resources/sap/uxap/themes/sap_belize/library_skeleton-RTL.css
# root/ui5/distribution/resources/sap/uxap/themes/sap_belize/library_skeleton.css
# root/ui5/distribution/resources/sap/uxap/themes/sap_belize/resources.json
# root/ui5/distribution/resources/sap/uxap/themes/sap_fiori_3/
# root/ui5/distribution/resources/sap/uxap/themes/sap_fiori_3/.theming
# root/ui5/distribution/resources/sap/uxap/themes/sap_fiori_3/css_variables.css
# root/ui5/distribution/resources/sap/uxap/themes/sap_fiori_3/css_variables.less
# root/ui5/distribution/resources/sap/uxap/themes/sap_fiori_3/css_variables.source.less
# root/ui5/distribution/resources/sap/uxap/themes/sap_fiori_3/library-RTL.css
# root/ui5/distribution/resources/sap/uxap/themes/sap_fiori_3/library-parameters.json
# root/ui5/distribution/resources/sap/uxap/themes/sap_fiori_3/library.css
# root/ui5/distribution/resources/sap/uxap/themes/sap_fiori_3/library.less
# root/ui5/distribution/resources/sap/uxap/themes/sap_fiori_3/library.source.less
# root/ui5/distribution/resources/sap/uxap/themes/sap_fiori_3/library_skeleton-RTL.css
# root/ui5/distribution/resources/sap/uxap/themes/sap_fiori_3/library_skeleton.css
# root/ui5/distribution/resources/sap/uxap/themes/sap_fiori_3/resources.json
# root/ui5/distribution/resources/sap-ui-core-nojQuery.js
# root/ui5/distribution/resources/sap-ui-core-nojQuery.js.map
# root/ui5/eve7/
# root/ui5/eve7/Component.js
# root/ui5/eve7/controller/
# root/ui5/eve7/controller/EveTable.controller.js
# root/ui5/eve7/controller/GL.controller.js
# root/ui5/eve7/controller/Ged.controller.js
# root/ui5/eve7/controller/GeomViewer.controller.js
# root/ui5/eve7/controller/Main.controller.js
# root/ui5/eve7/controller/Summary.controller.js
# root/ui5/eve7/css/
# root/ui5/eve7/css/eve.css
# root/ui5/eve7/geom.html
# root/ui5/eve7/index.html
# root/ui5/eve7/lib/
# root/ui5/eve7/lib/EveElements.js
# root/ui5/eve7/lib/EveElementsRCore.js
# root/ui5/eve7/lib/EveManager.js
# root/ui5/eve7/lib/EveScene.js
# root/ui5/eve7/lib/FXAAShader.js
# root/ui5/eve7/lib/GeomDrawing.js
# root/ui5/eve7/lib/GlViewer.js
# root/ui5/eve7/lib/GlViewerJSRoot.js
# root/ui5/eve7/lib/GlViewerRCore.js
# root/ui5/eve7/lib/GlViewerThree.js
# root/ui5/eve7/lib/OrbitControlsEve.js
# root/ui5/eve7/lib/OutlinePass.js
# root/ui5/eve7/lib/RendeQuTor.js
# root/ui5/eve7/manifest.json
# root/ui5/eve7/shaders/
# root/ui5/eve7/shaders/custom/
# root/ui5/eve7/shaders/custom/copyDepth2RReve.frag
# root/ui5/eve7/shaders/custom/copyDepth2RReve.vert
# root/ui5/eve7/shaders/custom/highPassReve.frag
# root/ui5/eve7/shaders/custom/highPassReve.vert
# root/ui5/eve7/shaders/custom/lowPassReve.frag
# root/ui5/eve7/shaders/custom/lowPassReve.vert
# root/ui5/eve7/shaders/programs.json
# root/ui5/eve7/view/
# root/ui5/eve7/view/EveTable.view.xml
# root/ui5/eve7/view/GL.view.xml
# root/ui5/eve7/view/Ged.view.xml
# root/ui5/eve7/view/GeomViewer.view.xml
# root/ui5/eve7/view/Main.view.xml
# root/ui5/eve7/view/MainMain.view.xml
# root/ui5/eve7/view/Summary.view.xml
# root/ui5/fitpanel/
# root/ui5/fitpanel/controller/
# root/ui5/fitpanel/controller/ColorButton.js
# root/ui5/fitpanel/controller/FitPanel.controller.js
# root/ui5/fitpanel/style/
# root/ui5/fitpanel/style/style.css
# root/ui5/fitpanel/view/
# root/ui5/fitpanel/view/FitPanel.view.xml
# root/ui5/panel/
# root/ui5/panel/Controller.js
# root/ui5/panel/panel.html
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# Cloning into 'PyROOT_in_Colab'...
# Checking out files: 100% (6494/6494), done.

# %%
# %%bash
# cp -r /opt/root/etc/notebook/kernels/root /usr/local/share/jupyter/kernels
# jupyter notebook --generate-config -y
# echo /opt/root/lib >> /etc/ld.so.conf
# ldconfig
# Out:
# Writing default config to: /root/.jupyter/jupyter_notebook_config.py
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link

# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.24/06

# %%
# %jsroot

# %%
c = ROOT.TCanvas("c", "title", 600, 400)
f = ROOT.TF1("f1", "sin(x)/x", -10., 10.)
f.Draw()
c.Draw()
# Out:
# <div id="root_plot_1633642984357"
#      style="width: 596px; height: 372px">
# </div>
# <script>
#
# function display_root_plot_1633642984357(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-12.5000001862645,"fY1":-0.445526868763038,"fX2":12.5000001862645,"fY2":1.22967102789839,"fXtoAbsPixelk":298.00005,"fXtoPixelk":298.00005,"fXtoPixel":23.8399996447563,"fYtoAbsPixelk":273.064876125825,"fYtoPixelk":273.064876125825,"fYtoPixel":-222.063316066343,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":596,"fVtoAbsPixelk":372.00005,"fVtoPixelk":372,"fVtoPixel":-372,"fAbsPixeltoXk":-12.5000001862645,"fPixeltoXk":-12.5000001862645,"fPixeltoX":0.041946309349881,"fAbsPixeltoYk":1.22967102789839,"fPixeltoYk":-0.445526868763038,"fPixeltoY":-0.00450322015231568,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":-10,"fUymin":-0.278007069111937,"fUxmax":10,"fUymax":1.06215122824729,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":-10,"fY1":-0.278007069111937,"fX2":10,"fY2":1.06215122824729,"fBorderSize":1,"fBorderMode":0},{"_typename":"TF1","fUniqueID":0,"fBits":8,"fName":"f1","fTitle":"sin(x)\/x","fLineColor":2,"fLineStyle":1,"fLineWidth":2,"fFillColor":19,"fFillStyle":0,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fXmin":-10,"fXmax":10,"fNpar":0,"fNdim":1,"fNpx":100,"fType":0,"fNpfits":0,"fNDF":0,"fChisquare":0,"fMinimum":-1111,"fMaximum":-1111,"fParErrors":[],"fParMin":[],"fParMax":[],"fSave":[],"fNormalized":false,"fNormIntegral":0,"fFormula":{"_typename":"TFormula","fUniqueID":0,"fBits":1024,"fName":"f1","fTitle":"sin(x)\/x","fClingParameters":[],"fAllParametersSetted":true,"fParams":[],"fFormula":"sin(x)\/x","fNdim":1,"fLinearParts":[],"fVectorized":false},"fParams":null,"fComposition":null},{"_typename":"TPaveText","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":0,"fX1":-1.6552013669463,"fY1":1.12402549111303,"fX2":1.6552013669463,"fY2":1.22129504640305,"fX1NDC":0.433791946308725,"fY1NDC":0.936935488639339,"fX2NDC":0.566208053691275,"fY2NDC":0.995000004768372,"fBorderSize":0,"fInit":1,"fShadowColor":1,"fCornerRadius":0,"fOption":"blNDC","fName":"title","fTextAngle":0,"fTextSize":0,"fTextAlign":22,"fTextColor":1,"fTextFont":42,"fLabel":"","fLongest":8,"fMargin":0.05,"fLines":{"_typename":"TList","name":"TList","arr":[{"_typename":"TLatex","fUniqueID":0,"fBits":0,"fName":"","fTitle":"sin(x)\/x","fTextAngle":0,"fTextSize":0,"fTextAlign":0,"fTextColor":0,"fTextFont":0,"fX":0,"fY":0,"fLineColor":1,"fLineStyle":1,"fLineWidth":2,"fLimitFactorSize":3,"fOriginSize":0.0493548400700092}],"opt":[""]}},{"_typename":"TStyle","fUniqueID":0,"fBits":0,"fName":"Modern","fTitle":"Modern Style","fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":19,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fTextAngle":0,"fTextSize":0.05,"fTextAlign":11,"fTextColor":1,"fTextFont":62,"fXaxis":{"_typename":"TAttAxis","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42},"fYaxis":{"_typename":"TAttAxis","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fL ...
#    Core.settings.HandleKeys = false;
#    Core.draw("root_plot_1633642984357", obj, "");
# }
#
# function script_load_root_plot_1633642984357(src, on_error) {
#     let script = document.createElement('script');
#     script.src = src;
#     script.onload = function() { display_root_plot_1633642984357(JSROOT); };
#     script.onerror = function() { script.remove(); on_error(); };
#     document.head.appendChild(script);
# }
#
# if (typeof requirejs !== 'undefined') {
#
#     // We are in jupyter notebooks, use require.js which should be configured already
#     requirejs.config({
#        paths: { 'JSRootCore' : [ 'scripts/JSRoot.core', 'https://root.cern/js/6.1.1/scripts/JSRoot.core.min', 'https://jsroot.gsi.de/6.1.1/scripts/JSRoot.core.min' ] }
#     })(['JSRootCore'],  function(Core) {
#        display_root_plot_1633642984357(C

# %%
# %%cpp
# void ABC(){
#     cout << "ABC" << endl;
# };

# %%
ROOT.ABC()
# Out:
# ABC
